# %%
# %matplotlib inline

# %%
source activate py2
# Out:
#   File "<ipython-input-6-ac5f6201433f>", line 1
#     source activate py2
#                   ^
# SyntaxError: invalid syntax

# %%
#Run this before training or throws an error
# %env THEANO_FLAGS='floatX=float32'
import os
os.environ["THEANO_FLAGS"] = "floatX=float32"
# Out:
# env: THEANO_FLAGS='floatX=float32'

# %%
#this code take 30 min to run
# %run -i  src/networkTraining.py src/LiviaNET_Config.ini 0
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named mkl
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
#  ******************************************  CREATING NETWORK ******************************************
#  --- Creating model (Reading parameters...)
#  **********************  Starting creation model **********************
#  ------------------------ General ------------------------
#  - Network name: liviaTest
#  - Folder to save the outputs: LiviaNet_Test
#  ------------------------ CNN Architecture ------------------------
#  - Number of classes: 9
#  - Layers: [10, 20, 30, 100]
#  - Kernel sizes: [[3, 3, 3], [3, 3, 3], [3, 3, 3], [1]]
#  - Intermediate connected CNN layers: []
#  - Pooling: [[1, 1, 1], [1, 1, 1], [1, 1, 1]]
#  - Dropout: [0.25, 0.5]
#  --- Activation function: PReLU
#  --- Weights initialization (CNN Layers): Delving
#  --- Weights initialization (FCN Layers): Delving
# ...

# %% [raw]
# CREATED NETWORK
# 3 epochs, 2 subepochs
# liviaTest_Epoch0  -- model created
# With 2 subepochs each, it created:
# liviaTest_Epoch1  -- epoch0 trained on
# liviaTest_Epoch2  -- epoch1 trained on
# liviaTest_Epoch3  -- epoch2 trained on

# %%
#see the last saved epoch
path="/mnt/d/JupyterNotebooks/LiviaNET/outputFiles/LiviaNet_Test/Networks"
# !ls {path}
# Out:
# liviaTest_Epoch0  liviaTest_Epoch1  liviaTest_Epoch2  liviaTest_Epoch3

# %%
#restart training from that epoch
# %run -i src/networkTraining.py src/LiviaNET_Config.ini 1 outputFiles/LiviaNet_Test/Networks/liviaTest_Epoch3
# Out:
#  ******************************************  STARTING NETWORK TRAINING ******************************************
#  ************************************************  STARTING TRAINING **************************************************
#  **********************  Starting training model (Reading parameters) **********************
#  --- Training model (Reading parameters...)
#  --- Do training in 3 epochs with 2 subEpochs each...
# -------- Reading Images names used in training/validation -------------
#  ================== Images for training ================
#  Image(0): MR_Img1.mat  |  GT: GT_Img1.mat  |  ROI ROI_Img1.mat
#  Image(1): MR_Img2.mat  |  GT: GT_Img2.mat  |  ROI ROI_Img2.mat
#  Image(2): MR_Img3.mat  |  GT: GT_Img3.mat  |  ROI ROI_Img3.mat
#  Image(3): MR_Img4.mat  |  GT: GT_Img4.mat  |  ROI ROI_Img4.mat
#  Image(4): MR_Img5.mat  |  GT: GT_Img5.mat  |  ROI ROI_Img5.mat
#  ================== Images for validation ================
# ...

# %% [raw]
# STARTED TRAINING
# Loaded liviaTest_Epoch3
#
# Created liviaTest_Epoch4, liviaTest_Epoch5, liviaTest_Epoch6

# %%
#see the last saved epoch
path="/mnt/d/JupyterNotebooks/LiviaNET/outputFiles/LiviaNet_Test/Networks"
# !ls {path}
# Out:
# liviaTest_Epoch0  liviaTest_Epoch2  liviaTest_Epoch4  liviaTest_Epoch6
# liviaTest_Epoch1  liviaTest_Epoch3  liviaTest_Epoch5

# %%
#trying to load model with pretrained weights
#Changed a line in ini file LiviaNET_Config.ini 
#weight_Initialization_CNN = 2
#weights folderName to LiviaNET/trainedWeights
# %run -i  src/networkTraining.py src/LiviaNET_Config.ini 1  outputFiles/LiviaNet_Test/Networks/liviaTest_Epoch6
# Out:
#  ******************************************  STARTING NETWORK TRAINING ******************************************
#  ************************************************  STARTING TRAINING **************************************************
#  **********************  Starting training model (Reading parameters) **********************
#  --- Training model (Reading parameters...)
#  --- Do training in 3 epochs with 2 subEpochs each...
# -------- Reading Images names used in training/validation -------------
#  ================== Images for training ================
#  Image(0): MR_Img1.mat  |  GT: GT_Img1.mat  |  ROI ROI_Img1.mat
#  Image(1): MR_Img2.mat  |  GT: GT_Img2.mat  |  ROI ROI_Img2.mat
#  Image(2): MR_Img3.mat  |  GT: GT_Img3.mat  |  ROI ROI_Img3.mat
#  Image(3): MR_Img4.mat  |  GT: GT_Img4.mat  |  ROI ROI_Img4.mat
#  Image(4): MR_Img5.mat  |  GT: GT_Img5.mat  |  ROI ROI_Img5.mat
#  ================== Images for validation ================
# ...

# %% [raw]
# ---------------------------------------------------------------------------------------------
# Extra Code

# %%
import sys
sys.executable
# Out:
# '/home/MAHEUNIX/anaconda3/bin/python'

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.8

# %%
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# ...
#     100% |████████████████████████████████| 3.2MB 2.4MB/s ta 0:00:011
# ...
#   Stored in directory: /home/MAHEUNIX/.cache/pip/wheels/81/75/d6/e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built bz2file
# ...
